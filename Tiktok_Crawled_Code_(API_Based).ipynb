# %%
# !pip install TikTokApi
# !playwright install chromium
# !apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libcups2 libdrm2 libxkbcommon0 libxcomposite1 libxdamage1 libxfixes3 libxrandr2 libgbm1 libasound2 libgstreamer-gl1.0-0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 18.5 MB/s eta 0:00:00
# ...
# (node:6331) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# ...

# %%
import pandas as pd
from TikTokApi import TikTokApi

ms_token = "l-GSc0wK9Rgy9DqDgWCjA6GOpOCRWEg7Dj2jD3_Dque2yaoi2yXV07MarTK_Jc3iCev_MVjip3KpVa0FDAa837BdepZwgQ_TpM0-hJ0ENm_PdvHkivpjgTUDV0AgnxCwmp5YHeeLY9rRP1XS6nVMoW2L"

async def scrape():
    comments = []
    async with TikTokApi() as api:
        await api.create_sessions(
            ms_tokens=[ms_token],
            num_sessions=1,
            sleep_after=10,
            headless=True,
            timeout=60000,
            browser='chromium'
        )
        video = api.video(url="https://www.tiktok.com/@sadampermanawiyana/video/7628218154258386197")
        async for comment in video.comments(count=1800):
            comments.append({
                "username": comment.author.username,
                "comment": comment.text,
                "likes": comment.likes_count,
            })
            print(f"[{len(comments)}] {comment.author.username}: {comment.text[:50]}")
    return comments

comments = await scrape()
df = pd.DataFrame(comments)
df.to_csv("comments.csv", index=False)
print(f"Total: {len(df)} comments")
df.head()
# Out:
# [1] ayydeln: sekelas ui...
# [2] 06fizii: ui lagi ui lagi.. UIIAAUUIIIAAAUIIIIAA
# [3] mojitowithberry: don't care...
# [4] zafiraaaaq: our future lawyer btw..
# [5] aycaa__6: sekelas top 1 loh
# [6] .hm_122: [Sticker] padahal FH, UI lagi
# [7] xsydle: ternyata bener yaa pendidikan tidak menentukan pol
# [8] whoopspiw: banyak, kebetulan UI doang yg ke up
# [9] ayaaaa4_4: fakultas hukum loh :(
# [10] xyzaxxkaxz: ahahaha udahlah guys UI gak seindah itu
# [11] homecity23: "ini yg ke publish doang" wtf 😔
# [12] jieee897: [Sticker] kampus itu lagii.
# [13] infphuwin03: [Sticker] f-fakultas hukum..?
# [14] jeeeremyy._: our future lawyer btw💜💜
# [15] urexpectation: [Sticker] sebagai calon hakim yang amanah dan bert
# [16] _.syifl0ove: [Sticker] belajarnya sampe ke UI, fakultas hukum,
# [17] m4tch4loverr_: FH loh☹️🥹
# [18] intann.taa15: fakultas hukum loh...
# [19] alxsnelux: [Sticker] ui ini, tidak jadi gokil
# [20] meowsl_: bahkan jurusan hukum yang harusnya jauh lebih nger
# ...
